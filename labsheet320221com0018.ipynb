# %% [markdown]
# <a href="https://colab.research.google.com/github/Adithya2254/DHV_labsheets/blob/main/labsheet_3com0005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/Meteorite_Landings.csv', nrows=5)
df
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5        21  Fell
# 1    Aarhus    2    Valid           H6       720  Fell
# 2      Abee    6    Valid          EH4    107000  Fell
# 3  Acapulco   10    Valid  Acapulcoite      1914  Fell
# 4   Achiras  370    Valid           L6       780  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
df.name
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %%
df.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
import requests

response = requests.get('https://data.nasa.gov/resource/gh4g-9sfh.json', params={'$limit':50_000})
if response.ok:
  payload=response.json()
else:
  print(f'REQUEST WAS NOT SUCCESSFUL ANDRETURNED CODE: {response.status_code}.')
  payload= None

# %%
import pandas as pd
dt=pd.DataFrame(payload)
dt.head(5)
# Out:
#        name   id nametype     recclass    mass  fall                     year  \
# 0    Aachen    1    Valid           L5      21  Fell  1880-01-01T00:00:00.000
# 1    Aarhus    2    Valid           H6     720  Fell  1951-01-01T00:00:00.000
# 2      Abee    6    Valid          EH4  107000  Fell  1952-01-01T00:00:00.000
# 3  Acapulco   10    Valid  Acapulcoite    1914  Fell  1976-01-01T00:00:00.000
# 4   Achiras  370    Valid           L6     780  Fell  1902-01-01T00:00:00.000
#
#        reclat      reclong                                        geolocation  \
# 0   50.775000     6.083330     {'latitude': '50.775', 'longitude': '6.08333'}
# 1   56.183330    10.233330  {'latitude': '56.18333', 'longitude': '10.23333'}
# 2   54.216670  -113.000000    {'latitude': '54.21667', 'longitude': '-113.0'}
# 3   16.883330   -99.900000     {'latitude': '16.88333', 'longitude': '-99.9'}
# 4  -33.166670   -64.950000   {'latitude': '-33.16667', 'longitude': '-64.95'}
#
# ...

# %%
df.shape
# Out:
# (5, 10)

# %%
df.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)         int64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
df.tail(10)
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5        21  Fell
# 1    Aarhus    2    Valid           H6       720  Fell
# 2      Abee    6    Valid          EH4    107000  Fell
# 3  Acapulco   10    Valid  Acapulcoite      1914  Fell
# 4   Achiras  370    Valid           L6       780  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         5 non-null      object
#  1   id           5 non-null      int64
#  2   nametype     5 non-null      object
#  3   recclass     5 non-null      object
#  4   mass (g)     5 non-null      int64
#  5   fall         5 non-null      object
#  6   year         5 non-null      object
#  7   reclat       5 non-null      float64
#  8   reclong      5 non-null      float64
#  9   GeoLocation  5 non-null      object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 528.0+ bytes

# %%
df.name
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %%
df[{'name','mass (g)'}]
# Out:
# <ipython-input-32-5c6e527a2818>:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[{'name','mass (g)'}]
#        name  mass (g)
# 0    Aachen        21
# 1    Aarhus       720
# 2      Abee    107000
# 3  Acapulco      1914
# 4   Achiras       780

# %%
df.iloc[100:104,[0,3,4,6]]
# Out:
# Empty DataFrame
# Columns: [name, recclass, mass (g), year]
# Index: []

# %%
df.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5        21  Fell
# 1    Aarhus    2    Valid           H6       720  Fell
# 2      Abee    6    Valid          EH4    107000  Fell
# 3  Acapulco   10    Valid  Acapulcoite      1914  Fell
# 4   Achiras  370    Valid           L6       780  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
(df['mass (g)']> 50) & (df.fall =='Found')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df[(df['mass (g)']  > 1e6)&(df.fall=='Fell')]
# Out:
# Empty DataFrame
# Columns: [name, id, nametype, recclass, mass (g), fall, year, reclat, reclong, GeoLocation]
# Index: []

# %%
df.query("`mass (g)`> 1e6 and fall == 'fell'")
# Out:
# Empty DataFrame
# Columns: [name, id, nametype, recclass, mass (g), fall, year, reclat, reclong, GeoLocation]
# Index: []

# %%
df.fall.value_counts()
# Out:
# Fell    5
# Name: fall, dtype: int64

# %%
df['mass (g)'].mean()
# Out:
# 22087.0

# %%
df['mass (g)'].quantile([0.01,0.05,0.5,0.95,0.99])
# Out:
# 0.01        48.96
# 0.05       160.80
# 0.50       780.00
# 0.95     85982.80
# 0.99    102796.56
# Name: mass (g), dtype: float64

# %%
df['mass (g)'].median()
# Out:
# 780.0

# %%
df['mass (g)'].max()
# Out:
# 107000

# %%
df.loc[df['mass (g)'].idxmax()]
# Out:
# name                             Abee
# id                                  6
# nametype                        Valid
# recclass                          EH4
# mass (g)                       107000
# fall                             Fell
# year           01/01/1952 12:00:00 AM
# reclat                       54.21667
# reclong                        -113.0
# GeoLocation        (54.21667, -113.0)
# Name: 2, dtype: object

# %%
df.recclass.nunique()
# Out:
# 5

# %%
df.recclass.unique()[:14]
# Out:
# array(['L5', 'H6', 'EH4', 'Acapulcoite', 'L6'], dtype=object)

# %%
df.describe(include ='all')
# Out:
#           name          id nametype recclass       mass (g)  fall  \
# count        5    5.000000        5        5       5.000000     5
# unique       5         NaN        1        5            NaN     1
# top     Aachen         NaN    Valid       L5            NaN  Fell
# freq         1         NaN        5        1            NaN     5
# mean       NaN   77.800000      NaN      NaN   22087.000000   NaN
# std        NaN  163.383598      NaN      NaN   47472.657372   NaN
# min        NaN    1.000000      NaN      NaN      21.000000   NaN
# 25%        NaN    2.000000      NaN      NaN     720.000000   NaN
# 50%        NaN    6.000000      NaN      NaN     780.000000   NaN
# 75%        NaN   10.000000      NaN      NaN    1914.000000   NaN
# max        NaN  370.000000      NaN      NaN  107000.000000   NaN
#
#                           year     reclat     reclong        GeoLocation
# count                        5   5.000000    5.000000                  5
# ...
